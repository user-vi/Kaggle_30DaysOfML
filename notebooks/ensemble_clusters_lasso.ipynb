# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PowerTransformer, MinMaxScaler
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import KBinsDiscretizer
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import StackingRegressor
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
import seaborn as sns


pd.set_option('display.max_columns', None)

# %%
try: 
    import optuna
except:
    # !pip install optuna
    import optuna

# %%
try:
    from CustomPipeline import *
except:
    import sys
    sys.path.insert(0,'/content/sample_data')
    from CustomPipeline import *
    print("ok")

# %%
test_ensemble = pd.read_csv("./en_test_ensemble.csv", delimiter=",", sep='.')
test = pd.read_csv("./en_test_witout_target.csv", delimiter=",", sep='.', index_col='id')
train_ensemble = pd.read_csv("./en_train_ensemble.csv", delimiter=",", sep='.')

# %%
df = pd.read_csv("./ensemble_with_clusters_1.csv", delimiter=",", sep='.')

# %% [markdown]
# # Feature engeneering with k-means

# %%
df.iloc[:, 25:]
# Out:
#                  0          1          label  k_means_cont0cont1  \
# 0       811.794579  802.49600           test                   6
# 1       841.286617  838.92790           test                   1
# 2       837.758268  841.12854           test                  12
# 3       853.769654  847.46990           test                   3
# 4       819.820749  811.22650           test                  13
# ...            ...        ...            ...                 ...
# 283995  869.400623  867.26910  test_ensemble                   7
# 283996  810.539736  808.34860  test_ensemble                   6
# 283997  808.015706  809.41300  test_ensemble                   8
# 283998  785.915281  782.50354  test_ensemble                   5
# 283999  806.721389  801.60360  test_ensemble                  14
#
#         k_means_cont0cont2  k_means_cont0cont3  k_means_cont0cont4  \
# 0                        5                   3                  13
# 1                       14                   9                   1
# 2                        6                  13                   4
# 3                        7                   4                  10
# 4                        3                   6                   1
# ...                    ...                 ...                 ...
# 283995                  12                  11                   9
# 283996                   5                   5                   0
# 283997                  14                   1                   1
# 283998                  14                  12                   5
# 283999                   4                  14                   0
#
#         k_means_cont0cont5  k_means_cont0cont6  k_means_cont0cont7  \
# 0                       11                   2                  11
# 1                        4                   3                   7
# 2                        7                   7                  10
# 3                        2                   8                   2
# 4                       13                   0                   8
# ...                    ...                 ...                 ...
# 283995                   3                   5                   5
# 283996                  11                   2                  13
# 283997                  13                   0                   7
# 283998                   6                   7                  15
# 283999                  11                  13                  11
#
#         k_means_cont0cont8  k_means_cont0cont9  k_means_cont0cont10  \
# 0                       13                  12                    8
# 1                        7                  10                    7
# 2                        5                   4                    7
# 3                       14                   5                   12
# 4                        7                   1                    1
# ...                    ...                 ...                  ...
# 283995                   0                   2                   14
# 283996                  13                  12                    3
# 283997                   7                  10                    0
# 283998                   1                   4                    0
# 283999                  11                  12                    3
#
#         k_means_cont0cont11  k_means_cont0cont12  k_means_cont0cont13  \
# 0                        12                   15                   13
# 1                        10                   13                   12
# 2                        15                   14                    2
# 3                         5                    5                    1
# 4                         0                    0                   11
# ...                     ...                  ...                  ...
# 283995                    1                    9                    5
# 283996                    9                   11                    6
# 283997                    0                    4                   11
# 283998                   15                    2                    3
# 283999                    9                   15                   13
#
#         k_means_cont00  k_means_cont01  k_means_cont1cont2  \
# 0                   11               8                  12
# 1                   15              14                  14
# 2                    6              15                  10
# 3                   10               1                   4
# 4                    8               6                   9
# ...                ...             ...                 ...
# 283995               4               4                   0
# 283996              11               6                   8
# 283997               1               6                  14
# 283998               3               3                  13
# 283999               1               8                   4
#
#         k_means_cont1cont3  k_means_cont1cont4  k_means_cont1cont5  \
# 0                        6                   2                   2
# 1                       11                   1                   9
# 2                        3                   3                   1
# 3                       11                   3                   1
# 4                       15                   5                  13
# ...                    ...                 ...                 ...
# 283995                   8                   1                   1
# 283996                  10                  10                  15
# 283997                   8                  10                  15
# 283998                   9                   7                   4
# 283999                   1                   1                   0
#
#         k_means_cont1cont6  k_means_cont1cont7  k_means_cont1cont8  \
# 0                        9                   5                   2
# 1                        3                   2                  15
# 2                        0                   2                   6
# 3                        3                   4                   8
# 4                        9                  11                   2
# ...                    ...                 ...                 ...
# 283995                   3                   1                  15
# 283996                   4                   8                  10
# 283997                   0                   2                   1
# 283998                   5                  12                   0
# 283999                   0                  15                  15
#
#         k_means_cont1cont9  k_means_cont1cont10  k_means_cont1cont11  \
# 0                        5                    3                    4
# 1                        2                   13                    8
# 2                        8                   13                    2
# 3                        6                    4                    9
# 4                       15                   14                   14
# ...                    ...                  ...                  ...
# 283995                  11                    7                    8
# 283996                   0                    9                   15
# 283997                   2                   12                    9
# 283998                  10                   15                    7
# 283999                   2                    0                    1
#
#         k_means_cont1cont12  k_means_cont1cont13  k_means_cont10  \
# 0                         1                    7              14
# 1                        12                   15              11
# 2                        10                    8               0
# 3                        10                    8               3
# 4                         2                    7               1
# ...                     ...                  ...             ...
# 283995                   12                    1              10
# 283996                    4                   13              14
# 283997                    3                   15               5
# 283998                    0                    2               7
# 283999                   10                    6               5
#
#         k_means_cont11  k_means_cont2cont3  k_means_cont2cont4  \
# 0                   15                   5                   1
# 1                   11                   2                  14
# 2                    1                   8                   4
# 3                   12                   2                   6
# 4                    0                  11                   0
# ...                ...                 ...                 ...
# 283995               4                  12                   8
# 283996              10                  15                   8
# 283997              10                   4                  14
# 283998               7                  10                   2
# 283999              15                  11                   0
#
#         k_means_cont2cont5  k_means_cont2cont6  k_means_cont2cont7  \
# 0                        1                  14                  11
# 1                       10                  12                   3
# 2                        3                  10                   3
# 3                       14                   2                  15
# 4                        0                   0                   7
# ...                    ...                 ...                 ...
# 283995                  10                   6                  10
# 283996                   1                   1                  10
# 283997                   8                   4                   0
# 283998                   8                   4                  14
# 283999                   0                   0                   7
#
#         k_means_cont2cont8  k_means_cont2cont9  k_means_cont2cont10  \
# 0                        5                   9                   14
# 1                        5                   9                    4
# 2                        0                   0                   12
# 3                        1                  10                    0
# 4                        2                  10                    8
# ...                    ...                 ...                  ...
# 283995                   3                   7                    5
# 283996                   9                   9                   10
# 283997                   5                  11                    2
# 283998                   5                  11                    2
# 283999                   2                   4                   13
#
#         k_means_cont2cont11  k_means_cont2cont12  k_means_cont2cont13  \
# 0                         8                    0                    1
# 1                        14                   12                   11
# 2                         2                    0                    2
# 3                        10                   14                    0
# 4                        10                   14                   10
# ...                     ...                  ...                  ...
# 283995                   14                   12                    8
# 283996                    4                    2                   12
# 283997                    0                    8                   10
# 283998                    0                    7                   10
# 283999                   15                   14                   10
#
#         k_means_cont20  k_means_cont21  k_means_cont3cont4  \
# 0                    0               1                   7
# 1                    1              10                   9
# 2                    8               5                   3
# 3                    9              13                   8
# 4                   13               9                   2
# ...                ...             ...                 ...
# 283995               3              12                   6
# 283996               0               9                   9
# 283997               6               9                   6
# 283998               7               3                   5
# 283999               6               1                   2
#
#         k_means_cont3cont5  k_means_cont3cont6  k_means_cont3cont7  \
# 0                        6                   8                   1
# 1                        4                  15                   5
# 2                        4                   2                  13
# 3                        4                  10                   0
# 4                        6                   8                  12
# ...                    ...                 ...                 ...
# 283995                   8                  12                   3
# 283996                  15                  11                   0
# 283997                  13                   5                   2
# 283998                   6                   8                  12
# 283999                   6                   8                   1
#
#         k_means_cont3cont8  k_means_cont3cont9  k_means_cont3cont10  \
# 0                        8                   2                    9
# 1                       13                  13                   10
# 2                        4                  14                    5
# 3                       12                   5                   14
# 4                        8                  12                    6
# ...                    ...                 ...                  ...
# 283995                   9                  11                    1
# 283996                   6                  13                    8
# 283997                   9                  15                    7
# 283998                   8                  10                    9
# 283999                   8                   2                   11
#
#         k_means_cont3cont11  k_means_cont3cont12  k_means_cont3cont13  \
# 0                         8                    0                    2
# 1                         5                    6                   12
# 2                         3                    4                   13
# 3                        11                    2                   15
# 4                         0                   13                    2
# ...                     ...                  ...                  ...
# 283995                    2                    3                   11
# 283996                   10                    2                    8
# 283997                    9                    3                    6
# 283998                   15                    0                    2
# 283999                    4                   13                    2
#
#         k_means_cont30  k_means_cont31  k_means_cont4cont5  \
# 0                    6               1                   4
# 1                    7               5                   7
# 2                    4               5                  10
# 3                    5               8                   3
# 4                   15              14                   2
# ...                ...             ...                 ...
# 283995              13               6                   0
# 283996               6              14                   2
# 283997              14              14                   2
# 283998               2               3                   8
# 283999              14               1                   2
#
#         k_means_cont4cont6  k_means_cont4cont7  k_means_cont4cont8  \
# 0                       11                  14                   7
# 1                        7                  13                  10
# 2                        9                   4                   8
# 3                        4                  11                  12
# 4                        1                  12                  10
# ...                    ...                 ...                 ...
# 283995                   7                  12                  10
# 283996                  10                   0                   1
# 283997                   1                  13                  10
# 283998                  12                   1                  14
# 283999                   1                   7                  10
#
#         k_means_cont4cont9  k_means_cont4cont10  k_means_cont4cont11  \
# 0                        9                    2                   14
# 1                        4                   12                    9
# 2                       15                   15                   10
# 3                        0                    7                   10
# 4                       13                    5                    0
# ...                    ...                  ...                  ...
# 283995                   2                    5                    9
# 283996                   4                    6                   12
# 283997                   4                    8                    0
# 283998                   6                   10                    1
# 283999                   4                    6                   12
#
#         k_means_cont4cont12  k_means_cont4cont13  k_means_cont40  \
# 0                         7                   14               6
# 1                        14                    8               8
# 2                         6                   10              15
# 3                         6                   10               1
# 4                         0                    6              11
# ...                     ...                  ...             ...
# 283995                   14                   15               5
# 283996                    5                    4               6
# 283997                    8                    8              14
# 283998                    9                   11               2
# 283999                    0                    6              14
#
#         k_means_cont41  k_means_cont5cont6  k_means_cont5cont7  \
# 0                   13                   9                   7
# 1                    4                   2                   8
# 2                   15                  15                   0
# 3                    0                  11                   2
# 4                    1                   9                   1
# ...                ...                 ...                 ...
# 283995               8                  11                   9
# 283996               1                   7                  11
# 283997               1                   9                  10
# 283998               3                   9                  11
# 283999              13                   9                   7
#
#         k_means_cont5cont8  k_means_cont5cont9  k_means_cont5cont10  \
# 0                        1                  12                    0
# 1                       11                  11                    6
# 2                       11                   2                   15
# 3                       15                   2                    8
# 4                        1                   0                    4
# ...                    ...                 ...                  ...
# 283995                  11                   1                    6
# 283996                   5                  12                    5
# 283997                   1                  12                    0
# 283998                   1                  10                    0
# 283999                   1                  12                    5
#
#         k_means_cont5cont11  k_means_cont5cont12  k_means_cont5cont13  \
# 0                        11                    1                    3
# 1                         8                    2                   10
# 2                         2                   11                   11
# 3                         2                    0                   11
# 4                         0                    1                    3
# ...                     ...                  ...                  ...
# 283995                    8                    2                    5
# 283996                    6                   15                    4
# 283997                    0                    4                   13
# 283998                    0                    7                    3
# 283999                    6                    1                    3
#
#         k_means_cont50  k_means_cont51  k_means_cont6cont7  \
# 0                    9               4                  11
# 1                    8               0                   4
# 2                   15               0                   3
# 3                    2              12                   2
# 4                    3              14                   1
# ...                ...             ...                 ...
# 283995               6               5                  15
# 283996               9              14                   5
# 283997               1              14                   3
# 283998              10               6                  14
# 283999               1               4                  11
#
#         k_means_cont6cont8  k_means_cont6cont9  k_means_cont6cont10  \
# 0                       12                  15                    8
# 1                        9                  11                   10
# 2                        4                   1                    2
# 3                        1                   0                    9
# 4                       12                   1                   11
# ...                    ...                 ...                  ...
# 283995                   9                   9                    3
# 283996                   6                   5                   12
# 283997                  12                  15                    8
# 283998                  12                   1                    8
# 283999                  12                  15                    1
#
#         k_means_cont6cont11  k_means_cont6cont12  k_means_cont6cont13  \
# 0                         5                   13                    7
# 1                        14                    7                    8
# 2                        10                   13                    0
# 3                         4                    0                    5
# 4                        10                   13                    7
# ...                     ...                  ...                  ...
# 283995                   14                    8                    9
# 283996                   15                   10                    6
# 283997                   10                   11                   12
# 283998                   10                    6                    7
# 283999                   15                   13                    7
#
#         k_means_cont60  k_means_cont61  k_means_cont7cont8  \
# 0                    9              10                  13
# 1                   12              12                   7
# 2                    4               7                   7
# 3                   15               0                   3
# 4                    8               1                  13
# ...                ...             ...                 ...
# 283995               6               4                  15
# 283996               9               1                   2
# 283997               3               1                   7
# 283998              14               2                  15
# 283999               3              10                  13
#
#         k_means_cont7cont9  k_means_cont7cont10  k_means_cont7cont11  \
# 0                        9                    5                   10
# 1                       10                   10                   12
# 2                        3                   10                    1
# 3                       13                    9                    6
# 4                       14                   12                    9
# ...                    ...                  ...                  ...
# 283995                   5                    7                    8
# 283996                  11                    4                    3
# 283997                  10                   15                    1
# 283998                   4                    6                   15
# 283999                   9                   11                   14
#
#         k_means_cont7cont12  k_means_cont7cont13  k_means_cont70  \
# 0                         9                    6              15
# 1                         0                   10              11
# 2                         5                    2               6
# 3                        14                   13               8
# 4                         1                    6              13
# ...                     ...                  ...             ...
# 283995                    7                    3               4
# 283996                   15                    1              15
# 283997                    2                   10               1
# 283998                   15                    0               3
# 283999                    4                    6               1
#
#         k_means_cont71  k_means_cont8cont9  k_means_cont8cont10  \
# 0                   11                  14                   10
# 1                    8                  14                   15
# 2                    1                   3                   15
# 3                   15                   9                    0
# 4                    6                  13                    8
# ...                ...                 ...                  ...
# 283995               4                   5                   14
# 283996               6                   7                    1
# 283997               6                  14                   10
# 283998              13                  13                   10
# 283999              11                  14                   13
#
#         k_means_cont8cont11  k_means_cont8cont12  k_means_cont8cont13  \
# 0                         6                   13                    9
# 1                        15                   11                   14
# 2                         1                    0                   13
# 3                         0                    4                    3
# 4                        12                    7                    9
# ...                     ...                  ...                  ...
# 283995                   15                   11                    7
# 283996                   14                   13                   10
# 283997                   12                   15                   14
# 283998                   12                   13                    2
# 283999                    2                    7                    2
#
#         k_means_cont80  k_means_cont81  k_means_cont9cont10  \
# 0                    1               6                    5
# 1                   12              10                   15
# 2                   12               1                    1
# 3                   10              14                    6
# 4                    5               8                    4
# ...                ...             ...                  ...
# 283995               4              15                    2
# 283996               1               8                    3
# 283997              15               8                    5
# 283998               2               3                    8
# 283999              15               6                    3
#
#         k_means_cont9cont11  k_means_cont9cont12  k_means_cont9cont13  \
# 0                         8                    7                    6
# 1                        11                   11                    7
# 2                         2                    1                   11
# 3                         7                    1                   11
# 4                         2                    1                    3
# ...                     ...                  ...                  ...
# 283995                   13                    2                   10
# 283996                   15                   13                    4
# 283997                    7                   15                    7
# 283998                    3                   10                    3
# 283999                   15                    7                    6
#
#         k_means_cont90  k_means_cont91  k_means_cont10cont11  \
# 0                    0              10                    13
# 1                   12              14                     4
# 2                    1              14                     8
# 3                    3               1                    15
# 4                    6               9                    10
# ...                ...             ...                   ...
# 283995              15               7                     4
# 283996               0               6                     3
# 283997               0               6                     1
# 283998               5              13                     1
# 283999              14              10                     3
#
#         k_means_cont10cont12  k_means_cont10cont13  k_means_cont100  \
# 0                         14                    10                5
# 1                         10                     6                7
# 2                          2                    12                4
# 3                         11                     9               14
# 4                          8                     0                0
# ...                      ...                   ...              ...
# 283995                     5                    13               11
# 283996                     4                     8                5
# 283997                     0                    10               15
# 283998                    14                    10                2
# 283999                     4                     2               15
#
#         k_means_cont101  k_means_cont11cont12  k_means_cont11cont13  \
# 0                    11                     6                    13
# 1                    12                    11                     7
# 2                    12                     0                     8
# 3                     1                     0                    10
# 4                     6                     0                     4
# ...                 ...                   ...                   ...
# 283995                7                    11                    11
# 283996                6                     4                     5
# 283997                6                     5                    14
# 283998               13                     8                    14
# 283999               11                     7                     0
#
#         k_means_cont110  k_means_cont111  k_means_cont12cont13  \
# 0                     1               13                     1
# 1                    12                0                     2
# 2                     0               15                     8
# 3                     2               15                     8
# 4                     7                6                     1
# ...                 ...              ...                   ...
# 283995                8               11                     6
# 283996                1                6                    12
# 283997               13                6                     5
# 283998                3               12                    10
# 283999               13               13                     1
#
#         k_means_cont120  k_means_cont121  k_means_cont130  k_means_cont131  \
# 0                     9               13                6               12
# 1                    15                6                7               10
# 2                    15                1                4                1
# 3                    14               14               12                8
# 4                     3                5                0                9
# ...                 ...              ...              ...              ...
# 283995                6                3                5                4
# 283996                9                5                6                9
# 283997                1                5               14                9
# 283998               13                4                2                7
# 283999                1               13               14               12
#
#         k_means_01  k_means_cont4_cont6_  k_means_cont5_cont8_  \
# 0                8                     0                     0
# 1                6                     0                     0
# 2                6                     0                     0
# 3                0                     0                     0
# 4                7                     0                     0
# ...            ...                   ...                   ...
# 283995           4                     0                     0
# 283996          11                     0                     0
# 283997          11                     0                     0
# 283998          12                     0                     0
# 283999           8                     0                     0
#
#         k_means_cont6_cont7_
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 283995                     0
# 283996                     0
# 283997                     0
# 283998                     0
# 283999                     0
#
# [284000 rows x 126 columns]

# %%
# cast int to obj
df.iloc[:, 28:] = df.iloc[:, 28:].astype('object')

# %%
df = df.iloc[:, 25:].copy()

# %%
df.head(2)
# Out:
#             0         1 label k_means_cont0cont1 k_means_cont0cont2  \
# 0  811.794579  802.4960  test                  6                  5
# 1  841.286617  838.9279  test                  1                 14
#
#   k_means_cont0cont3 k_means_cont0cont4 k_means_cont0cont5 k_means_cont0cont6  \
# 0                  3                 13                 11                  2
# 1                  9                  1                  4                  3
#
#   k_means_cont0cont7 k_means_cont0cont8 k_means_cont0cont9  \
# 0                 11                 13                 12
# 1                  7                  7                 10
#
#   k_means_cont0cont10 k_means_cont0cont11 k_means_cont0cont12  \
# 0                   8                  12                  15
# 1                   7                  10                  13
#
#   k_means_cont0cont13 k_means_cont00 k_means_cont01 k_means_cont1cont2  \
# 0                  13             11              8                 12
# 1                  12             15             14                 14
#
#   k_means_cont1cont3 k_means_cont1cont4 k_means_cont1cont5 k_means_cont1cont6  \
# 0                  6                  2                  2                  9
# 1                 11                  1                  9                  3
#
#   k_means_cont1cont7 k_means_cont1cont8 k_means_cont1cont9  \
# 0                  5                  2                  5
# 1                  2                 15                  2
#
#   k_means_cont1cont10 k_means_cont1cont11 k_means_cont1cont12  \
# 0                   3                   4                   1
# 1                  13                   8                  12
#
#   k_means_cont1cont13 k_means_cont10 k_means_cont11 k_means_cont2cont3  \
# 0                   7             14             15                  5
# 1                  15             11             11                  2
#
#   k_means_cont2cont4 k_means_cont2cont5 k_means_cont2cont6 k_means_cont2cont7  \
# 0                  1                  1                 14                 11
# 1                 14                 10                 12                  3
#
#   k_means_cont2cont8 k_means_cont2cont9 k_means_cont2cont10  \
# 0                  5                  9                  14
# 1                  5                  9                   4
#
#   k_means_cont2cont11 k_means_cont2cont12 k_means_cont2cont13 k_means_cont20  \
# 0                   8                   0                   1              0
# 1                  14                  12                  11              1
#
#   k_means_cont21 k_means_cont3cont4 k_means_cont3cont5 k_means_cont3cont6  \
# 0              1                  7                  6                  8
# 1             10                  9                  4                 15
#
#   k_means_cont3cont7 k_means_cont3cont8 k_means_cont3cont9  \
# 0                  1                  8                  2
# 1                  5                 13                 13
#
#   k_means_cont3cont10 k_means_cont3cont11 k_means_cont3cont12  \
# 0                   9                   8                   0
# 1                  10                   5                   6
#
#   k_means_cont3cont13 k_means_cont30 k_means_cont31 k_means_cont4cont5  \
# 0                   2              6              1                  4
# 1                  12              7              5                  7
#
#   k_means_cont4cont6 k_means_cont4cont7 k_means_cont4cont8 k_means_cont4cont9  \
# 0                 11                 14                  7                  9
# 1                  7                 13                 10                  4
#
#   k_means_cont4cont10 k_means_cont4cont11 k_means_cont4cont12  \
# 0                   2                  14                   7
# 1                  12                   9                  14
#
#   k_means_cont4cont13 k_means_cont40 k_means_cont41 k_means_cont5cont6  \
# 0                  14              6             13                  9
# 1                   8              8              4                  2
#
#   k_means_cont5cont7 k_means_cont5cont8 k_means_cont5cont9  \
# 0                  7                  1                 12
# 1                  8                 11                 11
#
#   k_means_cont5cont10 k_means_cont5cont11 k_means_cont5cont12  \
# 0                   0                  11                   1
# 1                   6                   8                   2
#
#   k_means_cont5cont13 k_means_cont50 k_means_cont51 k_means_cont6cont7  \
# 0                   3              9              4                 11
# 1                  10              8              0                  4
#
#   k_means_cont6cont8 k_means_cont6cont9 k_means_cont6cont10  \
# 0                 12                 15                   8
# 1                  9                 11                  10
#
#   k_means_cont6cont11 k_means_cont6cont12 k_means_cont6cont13 k_means_cont60  \
# 0                   5                  13                   7              9
# 1                  14                   7                   8             12
#
#   k_means_cont61 k_means_cont7cont8 k_means_cont7cont9 k_means_cont7cont10  \
# 0             10                 13                  9                   5
# 1             12                  7                 10                  10
#
#   k_means_cont7cont11 k_means_cont7cont12 k_means_cont7cont13 k_means_cont70  \
# 0                  10                   9                   6             15
# 1                  12                   0                  10             11
#
#   k_means_cont71 k_means_cont8cont9 k_means_cont8cont10 k_means_cont8cont11  \
# 0             11                 14                  10                   6
# 1              8                 14                  15                  15
#
#   k_means_cont8cont12 k_means_cont8cont13 k_means_cont80 k_means_cont81  \
# 0                  13                   9              1              6
# 1                  11                  14             12             10
#
#   k_means_cont9cont10 k_means_cont9cont11 k_means_cont9cont12  \
# 0                   5                   8                   7
# 1                  15                  11                  11
#
#   k_means_cont9cont13 k_means_cont90 k_means_cont91 k_means_cont10cont11  \
# 0                   6              0             10                   13
# 1                   7             12             14                    4
#
#   k_means_cont10cont12 k_means_cont10cont13 k_means_cont100 k_means_cont101  \
# 0                   14                   10               5              11
# 1                   10                    6               7              12
#
#   k_means_cont11cont12 k_means_cont11cont13 k_means_cont110 k_means_cont111  \
# 0                    6                   13               1              13
# 1                   11                    7              12               0
#
#   k_means_cont12cont13 k_means_cont120 k_means_cont121 k_means_cont130  \
# 0                    1               9              13               6
# 1                    2              15               6               7
#
#   k_means_cont131 k_means_01 k_means_cont4_cont6_ k_means_cont5_cont8_  \
# 0              12          8                    0                    0
# 1              10          6                    0                    0
#
#   k_means_cont6_cont7_
# 0                    0
# 1                    0

# %%
test_new = df[df['label'] == 'test'].drop('label', axis=1)
train_ensemble_new = df[df['label'] == 'train_ensemble'].drop('label', axis=1)
test_ensemble_new = df[df['label'] == 'test_ensemble'].drop('label', axis=1)

# %%
X = train_ensemble_new
y = train_ensemble['target']

num_train = X.select_dtypes([int, float])
cat_train = X.select_dtypes(object)

num = list(num_train)
cat = list(cat_train)
cat_features = [X.columns.get_loc(i) for i in cat]

rmse = make_scorer(mean_squared_error, squared=False)

pipeline_num = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('normal', PowerTransformer()), 
    ('scaling', MinMaxScaler()),  
#     ('bins', KBinsDiscretizer(n_bins = 50))
])
pipeline_cat = Pipeline(steps=[
#     ('encoding', OrdinalEncoder()),
    ('encoding', OneHotEncoder(handle_unknown='ignore')),
])
preprocessor = ColumnTransformer(n_jobs=-1,
    transformers=[
        ('num', pipeline_num, num),
        ('cat', pipeline_cat, cat),
        ], remainder="passthrough")


preprocessor.fit(df.drop('label', axis=1))
transform = preprocessor.transform(X)
X_test_ensemble = preprocessor.transform(test_ensemble_new)
X_test = preprocessor.transform(test_new)

# %%
def objective(trial):
    
    param_model = {
        'alpha': trial.suggest_float('alpha', 0.01, 1),
        'random_state':trial.suggest_categorical("random_state", [0, 1, 42]),
    }
    
    pipeline_ridge = Pipeline(steps=[ 
                                     ('feature_selection', SelectFromModel(linear_model.Lasso(alpha=0.6, random_state=1))),
                                     ('model', linear_model.Ridge(**param_model)),
                                     ])

    rmse_mean_cv = cross_val_score(pipeline_ridge, transform, y, cv=5, scoring=rmse)
    print(rmse_mean_cv)

    return rmse_mean_cv.mean()

# %%
study = optuna.create_study(direction="minimize", pruner=optuna.pruners.MedianPruner())
study.optimize(objective, n_trials=50)
# 72.05929420329886.
# 72.05702112640415.
# Out:
# [I 2021-08-31 22:22:00,726] A new study created in memory with name: no-name-058d2001-3821-450a-ab38-bdec066f0ccf
# [I 2021-08-31 22:22:55,903] Trial 0 finished with value: 72.08986131277832 and parameters: {'alpha': 0.08375057755463385, 'random_state': 1}. Best is trial 0 with value: 72.08986131277832.
# [72.3917034  72.28949453 71.6785645  71.88758008 72.20196405]
# C:\Users\User\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_coordinate_descent.py:516: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 487916.5534347892, tolerance: 24226.26554688837
#   max_iter, tol, rng, random, positive)
# C:\Users\User\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_coordinate_descent.py:516: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321275.68239212036, tolerance: 24230.12771687597
#   max_iter, tol, rng, random, positive)

# %%
best_params = study.best_trial.params
best_params

# %% [markdown]
# # check bias clusters

# %%
model = linear_model.Lasso(**best_params)
model.fit(transform, y)

# %%
model.coef_

# %%
X.head(2)

# %%
pred = model.predict(transform)
train_ensemble['pred_lasso'] = pred

# %%
pred = model.predict(X_test_ensemble)
print(mean_squared_error(test_ensemble["target"], pred, squared=False))

# %%
pred = model.predict(X_test)
test['target'] = pred / 100

# %% [markdown]
# # Residuals

# %%
train_ensemble['residuals'] = train_ensemble['target'] - train_ensemble['0']
train_ensemble['label'] = train_ensemble.residuals.apply(lambda x: 1 if x > -180 else 0)

# %%
sns.set(rc={'figure.figsize':(6.7,4.27)})
residuals = train_ensemble['target'] - train_ensemble['0']
sns.scatterplot(train_ensemble['0'], residuals, hue = train_ensemble['label'], size=train_ensemble['label'])

# %%
sns.set(rc={'figure.figsize':(6.7,4.27)})
residuals = train_ensemble['target'] - train_ensemble['pred_lasso']
sns.scatterplot(train_ensemble['pred_lasso'], residuals, hue = train_ensemble['label'], size=train_ensemble['label'])

# %% [markdown]
# # save predict

# %%
test.head()

# %%
test[['target']].to_csv('./ensemble_for_submit_with_clusters.csv', index=True)
